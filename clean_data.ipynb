# %%
import pandas as pd
import numpy as np
import re
import emoji
import string
import plotly.express as px

import nltk
from nltk.tokenize import TweetTokenizer  
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# %%
df = pd.read_csv('btc_2020_to_2022.csv')
df
# Out:
#                             date             user  \
# 0      2020-01-01 21:28:09+00:00      TheMoonCarl
# 1      2020-01-01 19:17:56+00:00     CryptoMichNL
# 2      2020-01-01 15:30:40+00:00        Bitsahara
# 3      2020-01-01 12:18:06+00:00    mishalederman
# 4      2020-01-01 12:11:39+00:00       CalvinAyre
# ...                          ...              ...
# 27495  2022-09-19 21:53:11+00:00   invest_answers
# 27496  2022-09-19 21:45:41+00:00  Nebraskangooner
# 27497  2022-09-19 21:44:25+00:00        mattcsnow
# 27498  2022-09-19 21:42:55+00:00       Danology10
# 27499  2022-09-19 21:35:45+00:00          apebayc
#
#                                                    tweet  likes  replies  \
# 0      ┏━━┓┏━━┓┏━━┓┏━━┓\n┗━┓┃┃┏┓┃┗━┓┃┃┏┓┃\n┏━┛┃┃┃┃┃┏━...    248       33
# 1      Q1 2020 will be 🔥 for the markets and altcoins...    259       26
# 2      0.0015 BTC New Year Giveaway!\n\n👉RETWEET &amp...    266      410
# 3      #Bitcoin has arrived to the #TRON ecosystem!\n...    190       15
# 4      I have been accused of being able to predict t...    237       22
# ...                                                  ...    ...      ...
# 27495  Historical Patterns, what it means for Crypto ...    138       42
# 27496      #Bitcoin\n\nDaily OBV https://t.co/d228TcvFfJ    211       46
# 27497  who is starting the #bitcoin + sauna conferenc...    122       35
# 27498  Keep calm and #HODL, while #BTC does the ol fl...    163       16
# 27499  Do you like scarce assets? \n\n120,600,000 $ET...    161       56
#
#        retweets
# 0            31
# 1            24
# 2           274
# 3            73
# 4            69
# ...         ...
# 27495        10
# 27496        14
# 27497         7
# 27498        23
# 27499        25
#
# [27500 rows x 6 columns]

# %%
df = df.astype({"tweet": str}, errors='raise')
df.dtypes
# Out:
# date        object
# user        object
# tweet       object
# likes        int64
# replies      int64
# retweets     int64
# dtype: object

# %% [markdown]
# ### 1. Removing null values if any

# %%
df.isna().any()
# Out:
# date        False
# user        False
# tweet       False
# likes       False
# replies     False
# retweets    False
# dtype: bool

# %% [markdown]
# * comment: likes, replies and retweets having 0 count is normal

# %% [markdown]
# #### 2. Dropping duplicate tweets

# %%
df.duplicated(subset='tweet').sum()
# Out:
# 92

# %%
df = df.drop_duplicates(subset=['tweet'])

# %% [markdown]
# #### 3. Lowercasing tweets content

# %%
df['tweet'] = df.tweet.str.lower()

# %%
df.head()
# Out:
#                         date           user  \
# 0  2020-01-01 21:28:09+00:00    TheMoonCarl
# 1  2020-01-01 19:17:56+00:00   CryptoMichNL
# 2  2020-01-01 15:30:40+00:00      Bitsahara
# 3  2020-01-01 12:18:06+00:00  mishalederman
# 4  2020-01-01 12:11:39+00:00     CalvinAyre
#
#                                                tweet  likes  replies  retweets
# 0  ┏━━┓┏━━┓┏━━┓┏━━┓\n┗━┓┃┃┏┓┃┗━┓┃┃┏┓┃\n┏━┛┃┃┃┃┃┏━...    248       33        31
# 1  q1 2020 will be 🔥 for the markets and altcoins...    259       26        24
# 2  0.0015 btc new year giveaway!\n\n👉retweet &amp...    266      410       274
# 3  #bitcoin has arrived to the #tron ecosystem!\n...    190       15        73
# 4  i have been accused of being able to predict t...    237       22        69

# %% [markdown]
# #### 4. Removing "@" and usernames

# %%
df.tweet = df.tweet.apply(lambda x: re.sub("@[A-Za-z0-9_]+", "", x))
df.head()
# Out:
#                         date           user  \
# 0  2020-01-01 21:28:09+00:00    TheMoonCarl
# 1  2020-01-01 19:17:56+00:00   CryptoMichNL
# 2  2020-01-01 15:30:40+00:00      Bitsahara
# 3  2020-01-01 12:18:06+00:00  mishalederman
# 4  2020-01-01 12:11:39+00:00     CalvinAyre
#
#                                                tweet  likes  replies  retweets
# 0  ┏━━┓┏━━┓┏━━┓┏━━┓\n┗━┓┃┃┏┓┃┗━┓┃┃┏┓┃\n┏━┛┃┃┃┃┃┏━...    248       33        31
# 1  q1 2020 will be 🔥 for the markets and altcoins...    259       26        24
# 2  0.0015 btc new year giveaway!\n\n👉retweet &amp...    266      410       274
# 3  #bitcoin has arrived to the #tron ecosystem!\n...    190       15        73
# 4  i have been accused of being able to predict t...    237       22        69

# %% [markdown]
# #### 5. Removing "#" symbol

# %%
df.tweet = df.tweet.apply(lambda x:  re.sub(r'#', '', x) )

# %% [markdown]
# #### 6. Removing emoji

# %%
df = df.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
df.head()
# Out:
#                         date           user  \
# 0  2020-01-01 21:28:09+00:00    TheMoonCarl
# 1  2020-01-01 19:17:56+00:00   CryptoMichNL
# 2  2020-01-01 15:30:40+00:00      Bitsahara
# 3  2020-01-01 12:18:06+00:00  mishalederman
# 4  2020-01-01 12:11:39+00:00     CalvinAyre
#
#                                                tweet likes replies retweets
# 0  \n\n                                       \n ...   248      33       31
# 1  q1 2020 will be  for the markets and altcoins....   259      26       24
# 2  0.0015 btc new year giveaway!\n\nretweet &amp;...   266     410      274
# 3  bitcoin has arrived to the tron ecosystem!\n\n...   190      15       73
# 4  i have been accused of being able to predict t...   237      22       69

# %%
def strip_links(text):
    link_regex    = re.compile('((https?):((//)|(\\\\))+([\w\d:#@%/;$()~_?\+-=\\\.&](#!)?)*)', re.DOTALL)
    links         = re.findall(link_regex, text)
    for link in links:
        text = text.replace(link[0], ', ')    
    return text

tests = df["tweet"]
temp = []
for t in tests:
    temp.append(strip_links(t))
df["tweet"] = temp
df.head()
# Out:
#                         date           user  \
# 0  2020-01-01 21:28:09+00:00    TheMoonCarl
# 1  2020-01-01 19:17:56+00:00   CryptoMichNL
# 2  2020-01-01 15:30:40+00:00      Bitsahara
# 3  2020-01-01 12:18:06+00:00  mishalederman
# 4  2020-01-01 12:11:39+00:00     CalvinAyre
#
#                                                tweet likes replies retweets
# 0  \n\n                                       \n ...   248      33       31
# 1  q1 2020 will be  for the markets and altcoins....   259      26       24
# 2  0.0015 btc new year giveaway!\n\nretweet &amp;...   266     410      274
# 3  bitcoin has arrived to the tron ecosystem!\n\n...   190      15       73
# 4  i have been accused of being able to predict t...   237      22       69

# %%
df.tweet =    df.tweet.apply(lambda x: re.sub(r'[0-9]', '', x) ) # removing single digit numbers

# %%
df.shape
# Out:
# (27408, 6)

# %%
df = df[~df.tweet.str.contains("bot")]
df = df[~df.tweet.str.contains("telegram")]
df = df[~df.tweet.str.contains("giveaway")]
df = df[~df.tweet.str.contains("earn free")]
df = df[~df.tweet.str.contains("video")]
df = df[~df.tweet.str.contains("follow and share")]

# %%
df.shape
# Out:
# (25961, 6)

# %%
df.head()
# Out:
#                         date           user  \
# 0  2020-01-01 21:28:09+00:00    TheMoonCarl
# 1  2020-01-01 19:17:56+00:00   CryptoMichNL
# 3  2020-01-01 12:18:06+00:00  mishalederman
# 4  2020-01-01 12:11:39+00:00     CalvinAyre
# 5  2020-01-01 07:59:23+00:00    TheMoonCarl
#
#                                                tweet likes replies retweets
# 0  \n\n                                       \n ...   248      33       31
# 1  q  will be  for the markets and altcoins. \n\n...   259      26       24
# 3  bitcoin has arrived to the tron ecosystem!\n\n...   190      15       73
# 4  i have been accused of being able to predict t...   237      22       69
# 5  my plans for :\n\n accumulate bitcoin \n accum...   758      91       97

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ryan.chang/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# instantiate the tokenizer class
tokenizer = TweetTokenizer(preserve_case=False, 
                           strip_handles=True,
                           reduce_len=True)
# tokenize the tweets
df["tokenized"] = df.tweet.apply(nltk.word_tokenize)
print('\nTokenized strings:')
df.head()
# Out:
# Tokenized strings:
#                         date           user  \
# 0  2020-01-01 21:28:09+00:00    TheMoonCarl
# 1  2020-01-01 19:17:56+00:00   CryptoMichNL
# 3  2020-01-01 12:18:06+00:00  mishalederman
# 4  2020-01-01 12:11:39+00:00     CalvinAyre
# 5  2020-01-01 07:59:23+00:00    TheMoonCarl
#
#                                                tweet likes replies retweets  \
# 0  \n\n                                       \n ...   248      33       31
# 1  q  will be  for the markets and altcoins. \n\n...   259      26       24
# 3  bitcoin has arrived to the tron ecosystem!\n\n...   190      15       73
# 4  i have been accused of being able to predict t...   237      22       69
# 5  my plans for :\n\n accumulate bitcoin \n accum...   758      91       97
#
#                                            tokenized
# 0                  [|, bitcoin, ,, not, altcoins, !]
# 1  [q, will, be, for, the, markets, and, altcoins...
# 3  [bitcoin, has, arrived, to, the, tron, ecosyst...
# 4  [i, have, been, accused, of, being, able, to, ...
# 5  [my, plans, for, :, accumulate, bitcoin, accum...

# %%
df["tweet"] = df["tweet"].apply(lambda x: "".join([word for word in x if word not in string.punctuation]))

# %%
# Function to remove punctuations and emojis

def remove_punct(text):
    # remove numbers
    text_nonum = re.sub(r'\d+', '', text)
    # remove punctuations and convert characters to lower case
    text_nopunct = "".join([char.lower() for char in text_nonum if char not in string.punctuation]) 
    # substitute multiple whitespace with single whitespace
    # Also, removes leading and trailing whitespaces
    text_no_doublespace = re.sub('\s+', ' ', text_nopunct).strip()
    return text_no_doublespace

df['tweet'] = df['tweet'].str.replace("[^a-zA-Z#!]", " ")
df.head()
# Out:
# /var/folders/1j/jmd55st94c545s4dclsj8_xw0000gs/T/ipykernel_81938/4225775154.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['tweet'] = df['tweet'].str.replace("[^a-zA-Z#!]", " ")
#                         date           user  \
# 0  2020-01-01 21:28:09+00:00    TheMoonCarl
# 1  2020-01-01 19:17:56+00:00   CryptoMichNL
# 3  2020-01-01 12:18:06+00:00  mishalederman
# 4  2020-01-01 12:11:39+00:00     CalvinAyre
# 5  2020-01-01 07:59:23+00:00    TheMoonCarl
#
#                                                tweet likes replies retweets  \
# 0                                                ...   248      33       31
# 1  q  will be  for the markets and altcoins   btc...   259      26       24
# 3  bitcoin has arrived to the tron ecosystem  enj...   190      15       73
# 4  i have been accused of being able to predict t...   237      22       69
# 5  my plans for    accumulate bitcoin   accumulat...   758      91       97
#
#                                            tokenized
# 0                  [|, bitcoin, ,, not, altcoins, !]
# 1  [q, will, be, for, the, markets, and, altcoins...
# 3  [bitcoin, has, arrived, to, the, tron, ecosyst...
# 4  [i, have, been, accused, of, being, able, to, ...
# 5  [my, plans, for, :, accumulate, bitcoin, accum...

# %%
df['tweet'] = df['tweet'].apply(remove_punct)

# %%
# instantiate the tokenizer class
tokenizer = TweetTokenizer(preserve_case=False, 
                           strip_handles=True,
                           reduce_len=True)
# tokenize the tweets
df["tokenized"] = df["tweet"].apply(nltk.word_tokenize)
print('\nTokenized strings:')
df.head(3)
# Out:
# Tokenized strings:
#                         date           user  \
# 0  2020-01-01 21:28:09+00:00    TheMoonCarl
# 1  2020-01-01 19:17:56+00:00   CryptoMichNL
# 3  2020-01-01 12:18:06+00:00  mishalederman
#
#                                                tweet likes replies retweets  \
# 0                               bitcoin not altcoins   248      33       31
# 1  q will be for the markets and altcoins btc bit...   259      26       24
# 3  bitcoin has arrived to the tron ecosystem enjo...   190      15       73
#
#                                            tokenized
# 0                           [bitcoin, not, altcoins]
# 1  [q, will, be, for, the, markets, and, altcoins...
# 3  [bitcoin, has, arrived, to, the, tron, ecosyst...

# %%
# Tokenize Data
tokenize_tweets = df['tweet'].apply(lambda x: x.split()) 
tokenize_tweets.head(10)
# Out:
# 0                              [bitcoin, not, altcoins]
# 1     [q, will, be, for, the, markets, and, altcoins...
# 3     [bitcoin, has, arrived, to, the, tron, ecosyst...
# 4     [i, have, been, accused, of, being, able, to, ...
# 5     [my, plans, for, accumulate, bitcoin, accumula...
# 6     [good, news, just, in, from, australia, bitcoi...
# 7     [heres, to, and, the, next, ten, years, may, t...
# 9     [tronwallet, introduces, a, completely, new, s...
# 10    [no, matter, how, far, bitcoin, falls, in, the...
# 11    [continuing, the, dec, trend, all, asset, clas...
# Name: tweet, dtype: object

# %%
stemmer = PorterStemmer()

tokenize_tweets = tokenize_tweets.apply(lambda x: [stemmer.stem(i) for i in x])
tokenize_tweets.head(10)
# Out:
# 0                               [bitcoin, not, altcoin]
# 1     [q, will, be, for, the, market, and, altcoin, ...
# 3     [bitcoin, ha, arriv, to, the, tron, ecosystem,...
# 4     [i, have, been, accus, of, be, abl, to, predic...
# 5     [my, plan, for, accumul, bitcoin, accumul, bit...
# 6     [good, news, just, in, from, australia, bitcoi...
# 7     [here, to, and, the, next, ten, year, may, thi...
# 9     [tronwallet, introduc, a, complet, new, swap, ...
# 10    [no, matter, how, far, bitcoin, fall, in, the,...
# 11    [continu, the, dec, trend, all, asset, class, ...
# Name: tweet, dtype: object

# %%
df.to_csv('btc_2020_to_2022_processed.csv')

# %%
# df = pd.read_csv('btc_2022_processed.csv', index_col=[0])
# df

# %%
from nltk.tag import pos_tag

def getAdjectives(tweet):
    tweet = word_tokenize(tweet)  # convert string to tokens
    tweet = [word for (word, tag) in pos_tag(tweet)
             if tag == "JJ"]  # pos_tag module in NLTK library
    return " ".join(tweet)  # join words with a space in between them

# %%
from textblob import TextBlob

# Create function to obtain Subjectivity Score
def getSubjectivity(tweet):
    return TextBlob(tweet).sentiment.subjectivity

# Create function to obtain Polarity Score
def getPolarity(tweet):
    return TextBlob(tweet).sentiment.polarity

# Create function to obtain Sentiment category
def getSentimentTextBlob(polarity):
    if polarity < 0:
        return "Negative"
    elif polarity == 0:
        return "Neutral"
    else:
        return "Positive"

# %%
from nltk.stem import WordNetLemmatizer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer


# function to return words to their base form using Lemmatizer
def preprocessTweetsSentiments(tweet):
    tweet_tokens = word_tokenize(tweet)
    lemmatizer = WordNetLemmatizer() # instatiate an object WordNetLemmatizer Class
    lemma_words = [lemmatizer.lemmatize(w) for w in tweet_tokens]
    return " ".join(lemma_words)

# %%
df["Tweets_Sentiments"] = df["tokenized"].astype("str").apply(preprocessTweetsSentiments)

# %%
# Apply all functions above to respective columns
#df_clean['Tweets_Sentiments'] = 0
df['Polarity'] = 0
df['Sentiment'] = 0
df['Subjectivity']=df['Tweets_Sentiments'].astype('str').apply(getSubjectivity)
df['Polarity']=df['Tweets_Sentiments'].astype('str').apply(getPolarity)
df['Sentiment']=df['Polarity'].apply(getSentimentTextBlob)

# %%
# See quick results of the Sentiment Analysis
df['Sentiment'].value_counts()
# Out:
# Positive    12347
# Neutral      9412
# Negative     4202
# Name: Sentiment, dtype: int64

# %%
# Create dataframe for Count of Sentiment Categories
bar_chart = df['Sentiment'].value_counts().rename_axis('Sentiment').to_frame('Total Tweets').reset_index()

# %%
bar_chart # Display dataframe
# Out:
#   Sentiment  Total Tweets
# 0  Positive         12347
# 1   Neutral          9412
# 2  Negative          4202

# %%
df
# Out:
#                             date             user  \
# 0      2020-01-01 21:28:09+00:00      TheMoonCarl
# 1      2020-01-01 19:17:56+00:00     CryptoMichNL
# 3      2020-01-01 12:18:06+00:00    mishalederman
# 4      2020-01-01 12:11:39+00:00       CalvinAyre
# 5      2020-01-01 07:59:23+00:00      TheMoonCarl
# ...                          ...              ...
# 27495  2022-09-19 21:53:11+00:00   invest_answers
# 27496  2022-09-19 21:45:41+00:00  Nebraskangooner
# 27497  2022-09-19 21:44:25+00:00        mattcsnow
# 27498  2022-09-19 21:42:55+00:00       Danology10
# 27499  2022-09-19 21:35:45+00:00          apebayc
#
#                                                    tweet likes replies  \
# 0                                   bitcoin not altcoins   248      33
# 1      q will be for the markets and altcoins btc bit...   259      26
# 3      bitcoin has arrived to the tron ecosystem enjo...   190      15
# 4      i have been accused of being able to predict t...   237      22
# 5      my plans for accumulate bitcoin accumulate bit...   758      91
# ...                                                  ...   ...     ...
# 27495  historical patterns what it means for crypto a...   138      42
# 27496                                  bitcoin daily obv   211      46
# 27497  who is starting the bitcoin sauna conference a...   122      35
# 27498  keep calm and hodl while btc does the ol flipp...   163      16
# 27499   do you like scarce assets eth btc bayc your call   161      56
#
#       retweets                                          tokenized  \
# 0           31                           [bitcoin, not, altcoins]
# 1           24  [q, will, be, for, the, markets, and, altcoins...
# 3           73  [bitcoin, has, arrived, to, the, tron, ecosyst...
# 4           69  [i, have, been, accused, of, being, able, to, ...
# 5           97  [my, plans, for, accumulate, bitcoin, accumula...
# ...        ...                                                ...
# 27495       10  [historical, patterns, what, it, means, for, c...
# 27496       14                              [bitcoin, daily, obv]
# 27497        7  [who, is, starting, the, bitcoin, sauna, confe...
# 27498       23  [keep, calm, and, hodl, while, btc, does, the,...
# 27499       25  [do, you, like, scarce, assets, eth, btc, bayc...
#
#                                        Tweets_Sentiments  Polarity Sentiment  \
# 0                  [ 'bitcoin ' , 'not ' , 'altcoins ' ]  0.000000   Neutral
# 1      [ ' q ' , 'will ' , 'be ' , 'for ' , 'the ' , ...  0.000000   Neutral
# 3      [ 'bitcoin ' , 'has ' , 'arrived ' , 'to ' , '...  0.400000  Positive
# 4      [ ' i ' , 'have ' , 'been ' , 'accused ' , 'of...  0.171510  Positive
# 5      [ 'my ' , 'plans ' , 'for ' , 'accumulate ' , ...  0.000000   Neutral
# ...                                                  ...       ...       ...
# 27495  [ 'historical ' , 'patterns ' , 'what ' , 'it ...  0.145455  Positive
# 27496                 [ 'bitcoin ' , 'daily ' , 'obv ' ]  0.000000   Neutral
# 27497  [ 'who ' , 'is ' , 'starting ' , 'the ' , 'bit...  0.000000   Neutral
# 27498  [ 'keep ' , 'calm ' , 'and ' , 'hodl ' , 'whil... -0.050000  Negative
# 27499  [ 'do ' , 'you ' , 'like ' , 'scarce ' , 'asse...  0.000000   Neutral
#
#        Subjectivity
# 0          0.000000
# 1          0.000000
# 3          0.500000
# 4          0.580032
# 5          0.000000
# ...             ...
# 27495      0.233333
# 27496      0.000000
# 27497      0.100000
# 27498      0.675000
# 27499      0.000000
#
# [25961 rows x 11 columns]

# %%
df.to_csv('btc_2020_to_2022_sentiment_nltk.csv', index=False)

# %% [markdown]
# # VADER
# ---

# %%
df = pd.read_csv("btc_processed.csv", index_col=[0])
df
# Out:
#                             date             user  \
# 0      2022-09-03 08:04:04+00:00   CharlieCryptoe
# 1      2022-09-03 08:04:01+00:00       altscanner
# 2      2022-09-03 08:04:00+00:00  SahbazzadeElsad
# 3      2022-09-03 08:04:00+00:00    AltCryptoGems
# 4      2022-09-03 08:03:59+00:00  CryptoCoachSami
# ...                          ...              ...
# 9999   2022-09-02 21:02:17+00:00     bruindesimon
# 10000  2022-09-02 21:02:16+00:00    BitomicWhales
# 10001  2022-09-02 21:02:13+00:00   ICOINOKLASTING
# 10002  2022-09-02 21:02:11+00:00  bmurphypointman
# 10003  2022-09-02 21:02:11+00:00          SEvpmcx
#
#                                                    tweet  likes  replies  \
# 0      everything bubble gonna pop housingcrisis this...    0.0      0.0
# 1                       chz is cooling down from btc btc    0.0      0.0
# 2      new x gem mc k holders cmc and cg dextools hot...    0.0      0.0
# 3      in a few years time it doesnt matter whether y...    0.0      0.0
# 4      btc hr chart price action longshort the breako...    0.0      1.0
# ...                                                  ...    ...      ...
# 9999   ft crypto watch sept curated post from publish...    0.0      0.0
# 10000                  someone just transfered btc m usd    0.0      0.0
# 10001  the cure for longcovid is long money or bitcoi...    0.0      2.0
# 10002  linkedin twitter facebook instagram tiktok soc...    0.0      0.0
# 10003  born sensitivelonely an cyptocurrency btc eth ...    0.0      0.0
#
#        retweets                                          tokenized
# 0           0.0  ['everything', 'bubble', 'gon', 'na', 'pop', '...
# 1           0.0  ['chz', 'is', 'cooling', 'down', 'from', 'btc'...
# 2           0.0  ['new', 'x', 'gem', 'mc', 'k', 'holders', 'cmc...
# 3           0.0  ['in', 'a', 'few', 'years', 'time', 'it', 'doe...
# 4           0.0  ['btc', 'hr', 'chart', 'price', 'action', 'lon...
# ...         ...                                                ...
# 9999        0.0  ['ft', 'crypto', 'watch', 'sept', 'curated', '...
# 10000       0.0  ['someone', 'just', 'transfered', 'btc', 'm', ...
# 10001       0.0  ['the', 'cure', 'for', 'longcovid', 'is', 'lon...
# 10002       0.0  ['linkedin', 'twitter', 'facebook', 'instagram...
# 10003       0.0  ['born', 'sensitivelonely', 'an', 'cyptocurren...
#
# [9410 rows x 7 columns]

# %%
# Calculate Polarity

analyser = SentimentIntensityAnalyzer()

scores = []
for sentence in df["tweet"].astype("str"):
  score = analyser.polarity_scores(sentence)
  scores.append(score)
  
scores = pd.DataFrame(scores)

df['Compound'] = scores['compound']
df['Negative'] = scores['neg']
df['Neutral'] = scores['neu']
df['Positive'] = scores['pos']

df
# Out:
#                             date             user  \
# 0      2022-09-03 08:04:04+00:00   CharlieCryptoe
# 1      2022-09-03 08:04:01+00:00       altscanner
# 2      2022-09-03 08:04:00+00:00  SahbazzadeElsad
# 3      2022-09-03 08:04:00+00:00    AltCryptoGems
# 4      2022-09-03 08:03:59+00:00  CryptoCoachSami
# ...                          ...              ...
# 9999   2022-09-02 21:02:17+00:00     bruindesimon
# 10000  2022-09-02 21:02:16+00:00    BitomicWhales
# 10001  2022-09-02 21:02:13+00:00   ICOINOKLASTING
# 10002  2022-09-02 21:02:11+00:00  bmurphypointman
# 10003  2022-09-02 21:02:11+00:00          SEvpmcx
#
#                                                    tweet  likes  replies  \
# 0      everything bubble gonna pop housingcrisis this...    0.0      0.0
# 1                       chz is cooling down from btc btc    0.0      0.0
# 2      new x gem mc k holders cmc and cg dextools hot...    0.0      0.0
# 3      in a few years time it doesnt matter whether y...    0.0      0.0
# 4      btc hr chart price action longshort the breako...    0.0      1.0
# ...                                                  ...    ...      ...
# 9999   ft crypto watch sept curated post from publish...    0.0      0.0
# 10000                  someone just transfered btc m usd    0.0      0.0
# 10001  the cure for longcovid is long money or bitcoi...    0.0      2.0
# 10002  linkedin twitter facebook instagram tiktok soc...    0.0      0.0
# 10003  born sensitivelonely an cyptocurrency btc eth ...    0.0      0.0
#
#        retweets                                          tokenized  Compound  \
# 0           0.0  ['everything', 'bubble', 'gon', 'na', 'pop', '...   -0.4226
# 1           0.0  ['chz', 'is', 'cooling', 'down', 'from', 'btc'...    0.0000
# 2           0.0  ['new', 'x', 'gem', 'mc', 'k', 'holders', 'cmc...    0.0000
# 3           0.0  ['in', 'a', 'few', 'years', 'time', 'it', 'doe...    0.2086
# 4           0.0  ['btc', 'hr', 'chart', 'price', 'action', 'lon...    0.0000
# ...         ...                                                ...       ...
# 9999        0.0  ['ft', 'crypto', 'watch', 'sept', 'curated', '...       NaN
# 10000       0.0  ['someone', 'just', 'transfered', 'btc', 'm', ...       NaN
# 10001       0.0  ['the', 'cure', 'for', 'longcovid', 'is', 'lon...       NaN
# 10002       0.0  ['linkedin', 'twitter', 'facebook', 'instagram...       NaN
# 10003       0.0  ['born', 'sensitivelonely', 'an', 'cyptocurren...       NaN
#
#        Negative  Neutral  Positive
# 0         0.111    0.833     0.056
# 1         0.000    1.000     0.000
# 2         0.000    1.000     0.000
# 3         0.037    0.897     0.066
# 4         0.000    1.000     0.000
# ...         ...      ...       ...
# 9999        NaN      NaN       NaN
# 10000       NaN      NaN       NaN
# 10001       NaN      NaN       NaN
# 10002       NaN      NaN       NaN
# 10003       NaN      NaN       NaN
#
# [9410 rows x 11 columns]

# %%
sentiment = []

pos = df['Positive'].tolist()
neg = df['Negative'].tolist()
neu = df['Neutral'].tolist()

for i in range(len(pos)):

    if pos[i] > neg[i] and pos[i] > neu[i]:
        sentiment.append("Positive")
    
    elif neg[i] > pos[i] and neg[i] > neu[i]:
        sentiment.append("Negative")

    else:
        sentiment.append("Neutral")

df["Sentiment"] = sentiment
df
# Out:
#                             date             user  \
# 0      2022-09-03 08:04:04+00:00   CharlieCryptoe
# 1      2022-09-03 08:04:01+00:00       altscanner
# 2      2022-09-03 08:04:00+00:00  SahbazzadeElsad
# 3      2022-09-03 08:04:00+00:00    AltCryptoGems
# 4      2022-09-03 08:03:59+00:00  CryptoCoachSami
# ...                          ...              ...
# 9999   2022-09-02 21:02:17+00:00     bruindesimon
# 10000  2022-09-02 21:02:16+00:00    BitomicWhales
# 10001  2022-09-02 21:02:13+00:00   ICOINOKLASTING
# 10002  2022-09-02 21:02:11+00:00  bmurphypointman
# 10003  2022-09-02 21:02:11+00:00          SEvpmcx
#
#                                                    tweet  likes  replies  \
# 0      everything bubble gonna pop housingcrisis this...    0.0      0.0
# 1                       chz is cooling down from btc btc    0.0      0.0
# 2      new x gem mc k holders cmc and cg dextools hot...    0.0      0.0
# 3      in a few years time it doesnt matter whether y...    0.0      0.0
# 4      btc hr chart price action longshort the breako...    0.0      1.0
# ...                                                  ...    ...      ...
# 9999   ft crypto watch sept curated post from publish...    0.0      0.0
# 10000                  someone just transfered btc m usd    0.0      0.0
# 10001  the cure for longcovid is long money or bitcoi...    0.0      2.0
# 10002  linkedin twitter facebook instagram tiktok soc...    0.0      0.0
# 10003  born sensitivelonely an cyptocurrency btc eth ...    0.0      0.0
#
#        retweets                                          tokenized  Compound  \
# 0           0.0  ['everything', 'bubble', 'gon', 'na', 'pop', '...   -0.4226
# 1           0.0  ['chz', 'is', 'cooling', 'down', 'from', 'btc'...    0.0000
# 2           0.0  ['new', 'x', 'gem', 'mc', 'k', 'holders', 'cmc...    0.0000
# 3           0.0  ['in', 'a', 'few', 'years', 'time', 'it', 'doe...    0.2086
# 4           0.0  ['btc', 'hr', 'chart', 'price', 'action', 'lon...    0.0000
# ...         ...                                                ...       ...
# 9999        0.0  ['ft', 'crypto', 'watch', 'sept', 'curated', '...       NaN
# 10000       0.0  ['someone', 'just', 'transfered', 'btc', 'm', ...       NaN
# 10001       0.0  ['the', 'cure', 'for', 'longcovid', 'is', 'lon...       NaN
# 10002       0.0  ['linkedin', 'twitter', 'facebook', 'instagram...       NaN
# 10003       0.0  ['born', 'sensitivelonely', 'an', 'cyptocurren...       NaN
#
#        Negative  Neutral  Positive Sentiment
# 0         0.111    0.833     0.056   Neutral
# 1         0.000    1.000     0.000   Neutral
# 2         0.000    1.000     0.000   Neutral
# 3         0.037    0.897     0.066   Neutral
# 4         0.000    1.000     0.000   Neutral
# ...         ...      ...       ...       ...
# 9999        NaN      NaN       NaN   Neutral
# 10000       NaN      NaN       NaN   Neutral
# 10001       NaN      NaN       NaN   Neutral
# 10002       NaN      NaN       NaN   Neutral
# 10003       NaN      NaN       NaN   Neutral
#
# [9410 rows x 12 columns]

# %%
df["Sentiment"].value_counts()
# Out:
# Neutral     9296
# Positive      82
# Negative      32
# Name: Sentiment, dtype: int64

# %%
df.to_csv('btc_sentiment_vader.csv', index=False)
